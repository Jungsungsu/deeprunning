# %%
# 광학문자인식(Optical Character recognition: OCR)

# %% [markdown]
# ### Tessaract API 활용
# - https://github.com/UB-Mannheim/tesseract/wiki
# - Additional language data 체크

# %%
# !pip install pytesseract
# Out:
# Collecting pytesseract
#   Downloading pytesseract-0.3.8.tar.gz (14 kB)
# Requirement already satisfied: Pillow in c:\users\smhrd\anaconda3\envs\deep1\lib\site-packages (from pytesseract) (8.4.0)
# Building wheels for collected packages: pytesseract
#   Building wheel for pytesseract (setup.py): started
#   Building wheel for pytesseract (setup.py): finished with status 'done'
#   Created wheel for pytesseract: filename=pytesseract-0.3.8-py2.py3-none-any.whl size=14070 sha256=fed17bfb2d1d5bcec6329611f881b1ed4b4b897a89b998f22014e7e9ed84b97f
#   Stored in directory: c:\users\smhrd\appdata\local\pip\cache\wheels\a4\89\b9\3f11250225d0f90e5454fcc30fd1b7208db226850715aa9ace
# Successfully built pytesseract
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.8

# %%
import pytesseract

# r : 뒤에 오는 문자열을 그대로 기억
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('./images/text.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)

# %%
text = pytesseract.image_to_string(img, lang= "eng")
print(text)
# Out:
# Life is a journey,
# not a guided tour.
#
# - Anonymous -

# %%
img = cv2.imread('./images/story.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)

# %%
text = pytesseract.image_to_string(img, lang= "kor")
print(text)
# Out:
# 소년
#
# 여기저기서 단풍잎 같은 슬픈 가을이 뚝뚝 떨어진다. 단풍잎
# 떨어져 나온 자리마다 봄을 마련해 놓고 나못가지 위에 하늘이
# 펼쳐 있다. 가만히 하늘을 들여다보려면 눈썸에 파란 물감이
# 든다. 두 손으로 따뜻한 볼을 쓸어 보면 손바닥에도 파란 물감
# 이 묻어난다. 다시 손바닥을 들여다본다. 손금에는 맑은 강물
# 이 흐르고, 맑은 강물이 흐르고, 강물 속에는 사랑처럼 슬픈 얼
# 굴ㅡ- 아름다운 순이의 얼굴이 어린다. 소년은 황홀히 눈을
# 감아 본다. 그래도 맑은 강물은 흘러 사랑처럼 슬픈 얼굴--
# 아름다운 순이의 얼굴은 어린다.

# %% [markdown]
# ### 번호판 인식

# %%
img = cv2.imread('./images/car.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Tesseract 전처리를 진행하여 인식율을 높여보자
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
_, img = cv2.threshold(img, 150, 255, cv2.THRESH_BINARY)

plt.imshow(img, cmap = 'gray')

# %%
text = pytesseract.image_to_string(img, lang= "kor")
print(text)
# Out:
# | 52가 3108
